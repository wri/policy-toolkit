# %%
from PIL import Image
from wand.image import Image as wimage
import os
import io
import pytesseract
import numpy as np
import re
from itertools import islice
from functools import reduce
import string

class Document:
    def __init__(self, path, titles = None):
        self.path = path
        self.name = self.path
    
    def get_images(self):
        page_images = []
        with wimage(filename=self.path, resolution=200) as img:
            for page_wand_image_seq in img.sequence:
                page_wand_image = wimage(page_wand_image_seq)
                page_jpeg_bytes = page_wand_image.make_blob(format="jpeg")
                page_jpeg_data = io.BytesIO(page_jpeg_bytes)
                page_image = Image.open(page_jpeg_data)
                page_images.append(page_image)
        self.images = page_images
        
    def process_images(self):
        self.text = np.array([pytesseract.image_to_string(x) for x in self.images])
        self.pages = [x for x in range(len(self.images))]
        
    def split_lines(self):
        self.lines = {}
        counter = 0
        pages = [re.split('\n', self.text[i]) for i in self.pages]
        for x, page in enumerate(pages):
            for i, line in enumerate(page):
                self.lines[i + counter] = [line, x]
            counter += len(page)
    
    def remove_titles(self):
        titles = [x for x in list(self.lines.keys()) if self.lines[x][0].lower() != self.lines[x][0] and\
                  len(self.lines[x][0]) <= 50]
        titles = [x for x in titles if self.lines[max(0, x - 1)][0].endswith('.') or\
                  self.lines[max(0, x - 1)][0] == '']
        print("Removing {} titles".format(len(titles)))
        for x in titles:
            del self.lines[x]
        self.lines = { key : value for key, value in zip(range(len(self.lines)), self.lines.values())}
        
    def combine_sentences(self):
        self.paragraphs = []
        ends = [0] + [i + 1 for i in self.lines.keys() if self.lines.get(i)[0].endswith('.')]
        sentence_ids = [(val, ends[x + 1]) for x, val in enumerate(ends) if val < max(ends)]
        for i in sentence_ids:
            lines = [self.lines.get(x)[0] for x in range(i[0], i[1])]
            self.paragraphs.append(' '.join(' '.join(lines).split()))
            
    def remove_headers(self):
        words = [x.replace(".pdf", "") for x in self.path.replace("/", " ").split(" ") if x not in ["..", "data", "raw"]]
        locs = []
        for i in reversed(range(3, len(words) + 1)):
            for x in window(words, n = i):
                locs.append(' '.join(x))

        self.clean = [reduce(lambda item, loc: item.replace(loc,''), [item]+locs)
            for item in self.paragraphs]
        
    def clean_data(self):
        self.clean = [re.sub("[\(\[].*?[\)\]]", "", x).lower() for x in self.clean]
        self.clean = [x.translate(str.maketrans('', '', string.punctuation)) for x in self.clean]
        
    def export_data(self):
        self.export_path = self.path.replace("raw", "processed")
        self.export_path = self.export_path.replace(".pdf", ".txt")
        with open(self.export_path, "w") as text_file:
            for x in self.clean:
                text_file.write(x)
                text_file.write('\n')

# %%
import pandas as pd

# %%
#localpath="D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/"
localpath='wri/policy-toolkit/'
filepath = localpath+"data/raw/malawi/"

#take policy documents in malawi as examples
filenames=[
    "Constituion.pdf",
    "Environment Management Act.pdf",
    "Forest Act – 1997.pdf",
    "Forest Landscape Restoration Strategy.pdf",
    "Malawi Government National Forest Policy - June 2016.pdf",
    "Malawi Growth and Development Strategy III .pdf",
    "mlw117757.pdf",
    "mlw118169.pdf",
    "mlw118196.pdf",
    "mlw169261.pdf",
    "mlw169262.pdf",
    "mlw169264.pdf",
    "mlw170882.pdf",
    "mlw170885.pdf",
    "mlw170908.pdf",
    "mlw170909.pdf",
    "National Environment Policy.pdf",
    "National forestry program.pdf",
    "National Land Policy 2002.pdf",
    "ROAM for Malawi.pdf",
    "Sector Policies Response.pdf",
    "Vision 2020.pdf"
]

# !pip install tesseract
# !pip install pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'
    
for file in filenames:
    filename=file
    doc = Document(filepath+filename)
    doc.get_images()

    doc.process_images()
    print("Images processed")

    doc.split_lines()
    doc.remove_titles()
    doc.combine_sentences()
    print("Sentences combined")

    def window(seq, n):
                "Returns a sliding window (of width n) over data from the iterable"
                "   s -> (s0,s1,...s[n-1]), (s1,s2,...,sn), ...                   "
                it = iter(seq)
                result = tuple(islice(it, n))
                if len(result) == n:
                    yield result
                for elem in it:
                    result = result[1:] + (elem,)
                    yield result
    doc.remove_headers()

    print("Text cleaned")

    doc.export_data()
    print("Exported data to: {}".format(doc.export_path))
# Out:
# Images processed
# Removing 645 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Constituion.txt
# Images processed
# Removing 203 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Environment Management Act.txt
# Images processed
# Removing 139 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Forest Act – 1997.txt
# Images processed
# Removing 507 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Forest Landscape Restoration Strategy.txt
# Images processed
# Removing 379 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Malawi Government National Forest Policy - June 2016.txt
# Images processed
# Removing 487 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Malawi Growth and Development Strategy III .txt
# Images processed
# Removing 24 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw117757.txt
# Images processed
# Removing 30 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw118169.txt
# Images processed
# Removing 26 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw118196.txt
# Images processed
# Removing 29 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw169261.txt
# Images processed
# Removing 43 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw169262.txt
# Images processed
# Removing 19 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw169264.txt
# Images processed
# Removing 133 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw170882.txt
# Images processed
# Removing 134 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw170885.txt
# Images processed
# Removing 150 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw170908.txt
# Images processed
# Removing 222 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/mlw170909.txt
# Images processed
# Removing 122 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/National Environment Policy.txt
# Images processed
# Removing 281 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/National forestry program.txt
# Images processed
# Removing 153 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/National Land Policy 2002.txt
# Images processed
# Removing 982 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/ROAM for Malawi.txt
# Images processed
# Removing 262 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Sector Policies Response.txt
# Images processed
# Removing 767 titles
# Sentences combined
# Text cleaned
# Exported data to: D:/personal/columbia university/capstone/policy-toolkit-master/policy-toolkit-master/data/processed/malawi/Vision 2020.txt

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import en_core_web_sm
nlp = en_core_web_sm.load()

class Nlp_sample_pipeline:
    def __init__(self, sentence, titles = None):
        self.corpus = sentence
        nlp.max_length = len(self.corpus)
        self.doc = nlp(self.corpus)
    
    def text_token(self):
        self.token_list=[]
        columns=["text","text_lower", "lemma", "lemma_lower","part_of_speech", "is_alphabet", "is_stopword"]
        for token in self.doc:
            self.token_list.append([token.text, token.lower_, token.lemma_, token.lemma_.lower(), token.pos_, token.is_alpha, token.is_stop])
        self.token_list=pd.DataFrame(self.token_list,columns=columns)
        return self.token_list
    
    def text_entities(self):
        self.entity_list = []
        columns=["text","text_lower", "label"]
        for ent in self.doc.ents:
            self.entity_list.append([ent.text, ent.lower_, ent.label_])
        self.entity_list=pd.DataFrame(self.entity_list,columns=columns)
        return self.entity_list
    
    def frequentwords(self):
        words = self.token_list[(self.token_list["is_alphabet"] == True) & (self.token_list["is_stopword"] == False) 
                       & (self.token_list["lemma_lower"].str.len() > 1)]["lemma_lower"].value_counts()[:5]
        sns.barplot(x=words.values, y=words.index, palette="Blues_d", linewidth=0)
        plt.xlabel("Ocurrences Count")
        plt.title("Most Frequent Words")
        plt.show()

        
def getTF(sentence):
    pip=Nlp_sample_pipeline(sentence)
    tokens=pip.text_token()
    tokens = tokens[(tokens["is_alphabet"] == True) & (tokens["is_stopword"] == False) 
                  & (tokens["lemma_lower"].str.len() > 1)]["lemma_lower"].value_counts()
    return tokens

# %%
from math import log

def cos_sim(a,b):
    dot_product=np.dot(a,b)
    norm_a=np.linalg.norm(a)
    norm_b=np.linalg.norm(b)
    return dot_product/(norm_a * norm_b)

def getTF(sentence):
    pip=Nlp_sample_pipeline(sentence)
    tokens=pip.text_token()
    tokens = tokens[(tokens["is_alphabet"] == True) & (tokens["is_stopword"] == False) 
                  & (tokens["lemma_lower"].str.len() > 1)]["lemma_lower"].value_counts()
    return tokens
    
def getIDF(term,dataset):
    totle=len(dataset)
    numDocumentsWithThisTerm = 0
    for item in dataset:
        if term.lower() in item.lower().split():
            numDocumentsWithThisTerm = numDocumentsWithThisTerm+1
    if numDocumentsWithThisTerm > 0:
        return 1.0 + log(float(len(dataset)) / numDocumentsWithThisTerm)
    else:
        return 1.0
    
def getSimilarity(sentence1,sentence2):
    tf1=getTF(sentence1)
    tf2=getTF(sentence2)
    all_words_list=[]
    for item in tf1.index:
        all_words_list.append(item)
    for item in tf2.index:
        if item not in all_words_list:
            all_words_list.append(item)
    all_words_list_size = len(all_words_list)
    
    v1=np.zeros(all_words_list_size, dtype=np.float)
    v2=np.zeros(all_words_list_size, dtype=np.float)
    i=0
    for item in all_words_list:
       # idf=getIDF(item,dataset)
        if item in tf1.index: 
            v1[i]=float(tf1[tf1.index==item])/float(len(tf1))
        else:
            v1[i]=0
        if item in tf2.index:
            v2[i]=float(tf2[tf2.index==item])/float(len(tf2))
        else:
            v2[i]=0
        i+=1
    return cos_sim(v1,v2)

# %%
## word2vec
import gensim, operator
from scipy import spatial
import numpy as np
from gensim.models import KeyedVectors

# the model can be downloaded through this link: https://github.com/mmihaltz/word2vec-GoogleNews-vectors
model_path = 'D:/personal/columbia university/NLP/'

def load_wordvec_model(modelName, modelFile, flagBin):
    print('Loading ' + modelName + ' model...')
    model = KeyedVectors.load_word2vec_format(model_path + modelFile, binary=flagBin)
    print('Finished loading ' + modelName + ' model...')
    return model

model_word2vec = load_wordvec_model('Word2Vec', 'GoogleNews-vectors-negative300.bin.gz', True)

def vec_similarity(input1, input2, vectors):
    term_vectors = [np.zeros(300), np.zeros(300)]
    terms = [input1, input2]
        
    for index, term in enumerate(terms):
        for i, t in enumerate(term.split(' ')):
            try:
                term_vectors[index] += vectors[t]
            except:
                term_vectors[index] += 0
        
    result = (1 - spatial.distance.cosine(term_vectors[0], term_vectors[1]))
    if result is 'nan':
        result = 0
        
    return result

# function checks whether the input words are present in the vocabulary for the model
def vocab_check(vectors, words):
    
    output = list()
    for word in words:
        if word in vectors.vocab:
            output.append(word.strip())
            
    return output

# function calculates similarity between two strings using a particular word vector model
def calc_similarity(input1, input2, vectors):
    s1words = set(vocab_check(vectors, input1.split()))
    s2words = set(vocab_check(vectors, input2.split()))
    
    output = vectors.n_similarity(s1words, s2words)
    return output
# Out:
# Loading Word2Vec model...
# Finished loading Word2Vec model...

# %%
filepath_exported = localpath+"data/processed/malawi/"

filenames_exported=[
    "Constituion.txt",
    "Environment Management Act.txt",
    "Forest Act – 1997.txt",
    "Forest Landscape Restoration Strategy.txt",
    "Malawi Government National Forest Policy - June 2016.txt",
    "Malawi Growth and Development Strategy III .txt",
    "mlw117757.txt",
    "mlw118169.txt",
    "mlw118196.txt",
    "mlw169261.txt",
    "mlw169262.txt",
    "mlw169264.txt",
    "mlw170882.txt",
    "mlw170885.txt",
    "mlw170908.txt",
    "mlw170909.txt",
    "National Environment Policy.txt",
    "National forestry program.txt",
    "National Land Policy 2002.txt",
    "ROAM for Malawi.txt",
    "Sector Policies Response.txt",
    "Vision 2020.txt"
]

matrix_tfidf=[[0]*len(filenames_exported) for i in range(len(filenames_exported))]
matrix_word2vec=[[0]*len(filenames_exported) for i in range(len(filenames_exported))]

for i in range(len(filenames_exported)-1):
    file1=filenames_exported[i]
    corpus1 = open(filepath_exported+file1, "r").read()
    for j in range(i+1,len(filenames_exported)):
        file2=filenames_exported[j]
        corpus2 = open(filepath_exported+file2, "r").read()
        
        result_tfidf=getSimilarity(corpus1,corpus2)
        matrix_tfidf[i][j]=result_tfidf
        
        print('The tfidf similarity between '+file1+' and '+file2+' is: ', result_tfidf)
        
        result_word2vec=calc_similarity(corpus1,corpus2, model_word2vec)
        matrix_word2vec[i][j] = result_word2vec
        
        print('The word2vec similarity between '+file1+' and '+file2+' is: ', result_word2vec)
        print()
# Out:
# The tfidf similarity between Constituion.txt and Environment Management Act.txt is:  0.4760148912617085
# The word2vec similarity between Constituion.txt and Environment Management Act.txt is:  0.9515735
#
# The tfidf similarity between Constituion.txt and Forest Act – 1997.txt is:  0.30718133520423696
# The word2vec similarity between Constituion.txt and Forest Act – 1997.txt is:  0.93888366
#
# The tfidf similarity between Constituion.txt and Forest Landscape Restoration Strategy.txt is:  0.11138216886792228
# The word2vec similarity between Constituion.txt and Forest Landscape Restoration Strategy.txt is:  0.8562411
#
# The tfidf similarity between Constituion.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.08461887961927006
# The word2vec similarity between Constituion.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.88249576
#
# The tfidf similarity between Constituion.txt and Malawi Growth and Development Strategy III .txt is:  0.14019304617574396
# The word2vec similarity between Constituion.txt and Malawi Growth and Development Strategy III .txt is:  0.8510469
#
# The tfidf similarity between Constituion.txt and mlw117757.txt is:  0.22404882099536305
# The word2vec similarity between Constituion.txt and mlw117757.txt is:  0.8949572
#
# The tfidf similarity between Constituion.txt and mlw118169.txt is:  0.42342398556615485
# The word2vec similarity between Constituion.txt and mlw118169.txt is:  0.9302585
#
# The tfidf similarity between Constituion.txt and mlw118196.txt is:  0.10098577825534824
# The word2vec similarity between Constituion.txt and mlw118196.txt is:  0.87802964
#
# The tfidf similarity between Constituion.txt and mlw169261.txt is:  0.2766466092622441
# The word2vec similarity between Constituion.txt and mlw169261.txt is:  0.91422236
#
# The tfidf similarity between Constituion.txt and mlw169262.txt is:  0.3290398707473472
# The word2vec similarity between Constituion.txt and mlw169262.txt is:  0.9342656
#
# The tfidf similarity between Constituion.txt and mlw169264.txt is:  0.08306056763766506
# The word2vec similarity between Constituion.txt and mlw169264.txt is:  0.71877563
#
# The tfidf similarity between Constituion.txt and mlw170882.txt is:  0.29280222767066877
# The word2vec similarity between Constituion.txt and mlw170882.txt is:  0.9571016
#
# The tfidf similarity between Constituion.txt and mlw170885.txt is:  0.3787328794261079
# The word2vec similarity between Constituion.txt and mlw170885.txt is:  0.9370979
#
# The tfidf similarity between Constituion.txt and mlw170908.txt is:  0.3867575661374893
# The word2vec similarity between Constituion.txt and mlw170908.txt is:  0.9469882
#
# The tfidf similarity between Constituion.txt and mlw170909.txt is:  0.37488208497881637
# The word2vec similarity between Constituion.txt and mlw170909.txt is:  0.9524691
#
# The tfidf similarity between Constituion.txt and National Environment Policy.txt is:  0.17639432785411602
# The word2vec similarity between Constituion.txt and National Environment Policy.txt is:  0.87024546
#
# The tfidf similarity between Constituion.txt and National forestry program.txt is:  0.1361478156341509
# The word2vec similarity between Constituion.txt and National forestry program.txt is:  0.88472265
#
# The tfidf similarity between Constituion.txt and National Land Policy 2002.txt is:  0.14879685423665154
# The word2vec similarity between Constituion.txt and National Land Policy 2002.txt is:  0.9178057
#
# The tfidf similarity between Constituion.txt and ROAM for Malawi.txt is:  0.1290421858325458
# The word2vec similarity between Constituion.txt and ROAM for Malawi.txt is:  0.8740119
#
# The tfidf similarity between Constituion.txt and Sector Policies Response.txt is:  0.1228203140552621
# The word2vec similarity between Constituion.txt and Sector Policies Response.txt is:  0.8664963
#
# The tfidf similarity between Constituion.txt and Vision 2020.txt is:  0.15240088975856164
# The word2vec similarity between Constituion.txt and Vision 2020.txt is:  0.8900187
#
# The tfidf similarity between Environment Management Act.txt and Forest Act – 1997.txt is:  0.43749070690181535
# The word2vec similarity between Environment Management Act.txt and Forest Act – 1997.txt is:  0.9794727
#
# The tfidf similarity between Environment Management Act.txt and Forest Landscape Restoration Strategy.txt is:  0.21807715101119574
# The word2vec similarity between Environment Management Act.txt and Forest Landscape Restoration Strategy.txt is:  0.9076868
#
# The tfidf similarity between Environment Management Act.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.22617843884575473
# The word2vec similarity between Environment Management Act.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.90027213
#
# The tfidf similarity between Environment Management Act.txt and Malawi Growth and Development Strategy III .txt is:  0.23169770729025993
# The word2vec similarity between Environment Management Act.txt and Malawi Growth and Development Strategy III .txt is:  0.86485505
#
# The tfidf similarity between Environment Management Act.txt and mlw117757.txt is:  0.33831571082890405
# The word2vec similarity between Environment Management Act.txt and mlw117757.txt is:  0.93688345
#
# The tfidf similarity between Environment Management Act.txt and mlw118169.txt is:  0.3744795556221529
# The word2vec similarity between Environment Management Act.txt and mlw118169.txt is:  0.94041157
#
# The tfidf similarity between Environment Management Act.txt and mlw118196.txt is:  0.12625771121476528
# The word2vec similarity between Environment Management Act.txt and mlw118196.txt is:  0.93099284
#
# The tfidf similarity between Environment Management Act.txt and mlw169261.txt is:  0.3071114388708335
# The word2vec similarity between Environment Management Act.txt and mlw169261.txt is:  0.9236926
#
# The tfidf similarity between Environment Management Act.txt and mlw169262.txt is:  0.32770271530857914
# The word2vec similarity between Environment Management Act.txt and mlw169262.txt is:  0.9339344
#
# The tfidf similarity between Environment Management Act.txt and mlw169264.txt is:  0.11583217519127519
# The word2vec similarity between Environment Management Act.txt and mlw169264.txt is:  0.7220132
#
# The tfidf similarity between Environment Management Act.txt and mlw170882.txt is:  0.29995269682581077
# The word2vec similarity between Environment Management Act.txt and mlw170882.txt is:  0.96486104
#
# The tfidf similarity between Environment Management Act.txt and mlw170885.txt is:  0.42864286617989866
# The word2vec similarity between Environment Management Act.txt and mlw170885.txt is:  0.9630982
#
# The tfidf similarity between Environment Management Act.txt and mlw170908.txt is:  0.39177669979135193
# The word2vec similarity between Environment Management Act.txt and mlw170908.txt is:  0.96657735
#
# The tfidf similarity between Environment Management Act.txt and mlw170909.txt is:  0.42264495813061703
# The word2vec similarity between Environment Management Act.txt and mlw170909.txt is:  0.9757683
#
# The tfidf similarity between Environment Management Act.txt and National Environment Policy.txt is:  0.5403892155220933
# The word2vec similarity between Environment Management Act.txt and National Environment Policy.txt is:  0.9360534
#
# The tfidf similarity between Environment Management Act.txt and National forestry program.txt is:  0.21248410519849092
# The word2vec similarity between Environment Management Act.txt and National forestry program.txt is:  0.9302239
#
# The tfidf similarity between Environment Management Act.txt and National Land Policy 2002.txt is:  0.19095121963532588
# The word2vec similarity between Environment Management Act.txt and National Land Policy 2002.txt is:  0.96052456
#
# The tfidf similarity between Environment Management Act.txt and ROAM for Malawi.txt is:  0.25124723452368003
# The word2vec similarity between Environment Management Act.txt and ROAM for Malawi.txt is:  0.9174687
#
# The tfidf similarity between Environment Management Act.txt and Sector Policies Response.txt is:  0.2659605216972826
# The word2vec similarity between Environment Management Act.txt and Sector Policies Response.txt is:  0.9290371
#
# The tfidf similarity between Environment Management Act.txt and Vision 2020.txt is:  0.24773021849854268
# The word2vec similarity between Environment Management Act.txt and Vision 2020.txt is:  0.921925
#
# The tfidf similarity between Forest Act – 1997.txt and Forest Landscape Restoration Strategy.txt is:  0.4512803956318628
# The word2vec similarity between Forest Act – 1997.txt and Forest Landscape Restoration Strategy.txt is:  0.90450466
#
# The tfidf similarity between Forest Act – 1997.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.56175800600997
# The word2vec similarity between Forest Act – 1997.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.8842975
#
# The tfidf similarity between Forest Act – 1997.txt and Malawi Growth and Development Strategy III .txt is:  0.19135309342823983
# The word2vec similarity between Forest Act – 1997.txt and Malawi Growth and Development Strategy III .txt is:  0.8513373
#
# The tfidf similarity between Forest Act – 1997.txt and mlw117757.txt is:  0.24875179840203712
# The word2vec similarity between Forest Act – 1997.txt and mlw117757.txt is:  0.9325224
#
# The tfidf similarity between Forest Act – 1997.txt and mlw118169.txt is:  0.28911407332061806
# The word2vec similarity between Forest Act – 1997.txt and mlw118169.txt is:  0.9548415
#
# The tfidf similarity between Forest Act – 1997.txt and mlw118196.txt is:  0.21463692290631753
# The word2vec similarity between Forest Act – 1997.txt and mlw118196.txt is:  0.9467685
#
# The tfidf similarity between Forest Act – 1997.txt and mlw169261.txt is:  0.31749421150973256
# The word2vec similarity between Forest Act – 1997.txt and mlw169261.txt is:  0.9196991
#
# The tfidf similarity between Forest Act – 1997.txt and mlw169262.txt is:  0.27383149607367846
# The word2vec similarity between Forest Act – 1997.txt and mlw169262.txt is:  0.9341867
#
# The tfidf similarity between Forest Act – 1997.txt and mlw169264.txt is:  0.08392365901154039
# The word2vec similarity between Forest Act – 1997.txt and mlw169264.txt is:  0.72099155
#
# The tfidf similarity between Forest Act – 1997.txt and mlw170882.txt is:  0.3807673523676847
# The word2vec similarity between Forest Act – 1997.txt and mlw170882.txt is:  0.9657797
#
# The tfidf similarity between Forest Act – 1997.txt and mlw170885.txt is:  0.41875786960051187
# The word2vec similarity between Forest Act – 1997.txt and mlw170885.txt is:  0.971948
#
# The tfidf similarity between Forest Act – 1997.txt and mlw170908.txt is:  0.34511088525936856
# The word2vec similarity between Forest Act – 1997.txt and mlw170908.txt is:  0.9624306
#
# The tfidf similarity between Forest Act – 1997.txt and mlw170909.txt is:  0.37544954177124346
# The word2vec similarity between Forest Act – 1997.txt and mlw170909.txt is:  0.97442317
#
# The tfidf similarity between Forest Act – 1997.txt and National Environment Policy.txt is:  0.30354949237882445
# The word2vec similarity between Forest Act – 1997.txt and National Environment Policy.txt is:  0.92899203
#
# The tfidf similarity between Forest Act – 1997.txt and National forestry program.txt is:  0.536876442648096
# The word2vec similarity between Forest Act – 1997.txt and National forestry program.txt is:  0.92559814
#
# The tfidf similarity between Forest Act – 1997.txt and National Land Policy 2002.txt is:  0.29932571374797395
# The word2vec similarity between Forest Act – 1997.txt and National Land Policy 2002.txt is:  0.9582318
#
# The tfidf similarity between Forest Act – 1997.txt and ROAM for Malawi.txt is:  0.44174196870132526
# The word2vec similarity between Forest Act – 1997.txt and ROAM for Malawi.txt is:  0.9066833
#
# The tfidf similarity between Forest Act – 1997.txt and Sector Policies Response.txt is:  0.1817429181397685
# The word2vec similarity between Forest Act – 1997.txt and Sector Policies Response.txt is:  0.9207194
#
# The tfidf similarity between Forest Act – 1997.txt and Vision 2020.txt is:  0.1850318546851648
# The word2vec similarity between Forest Act – 1997.txt and Vision 2020.txt is:  0.91670513
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.5617447040272533
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and Malawi Government National Forest Policy - June 2016.txt is:  0.96692383
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and Malawi Growth and Development Strategy III .txt is:  0.457625116843107
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and Malawi Growth and Development Strategy III .txt is:  0.9576914
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw117757.txt is:  0.04854339989820531
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw117757.txt is:  0.8111509
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw118169.txt is:  0.11190081884617406
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw118169.txt is:  0.84373903
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw118196.txt is:  0.15322208701246562
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw118196.txt is:  0.8802855
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw169261.txt is:  0.14615306543070108
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw169261.txt is:  0.81565046
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw169262.txt is:  0.06886887066466978
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw169262.txt is:  0.81008697
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw169264.txt is:  0.06753377533361223
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw169264.txt is:  0.6490332
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw170882.txt is:  0.20826769697809402
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw170882.txt is:  0.8396981
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw170885.txt is:  0.20939831309145873
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw170885.txt is:  0.84458935
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw170908.txt is:  0.11400335634734148
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw170908.txt is:  0.83901066
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and mlw170909.txt is:  0.22856811754410888
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and mlw170909.txt is:  0.8681176
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and National Environment Policy.txt is:  0.4899393745630319
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and National Environment Policy.txt is:  0.97444606
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and National forestry program.txt is:  0.6011206859132168
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and National forestry program.txt is:  0.9790678
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and National Land Policy 2002.txt is:  0.3715597216206319
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and National Land Policy 2002.txt is:  0.9507288
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and ROAM for Malawi.txt is:  0.9050726716285215
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and ROAM for Malawi.txt is:  0.97915524
#
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and Sector Policies Response.txt is:  0.50297406208653
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and Sector Policies Response.txt is:  0.97959924
# The tfidf similarity between Forest Landscape Restoration Strategy.txt and Vision 2020.txt is:  0.46717493404129184
# The word2vec similarity between Forest Landscape Restoration Strategy.txt and Vision 2020.txt is:  0.9721744
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and Malawi Growth and Development Strategy III .txt is:  0.4461252878172951
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and Malawi Growth and Development Strategy III .txt is:  0.96838343
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw117757.txt is:  0.06514455058819969
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw117757.txt is:  0.80237293
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw118169.txt is:  0.08203358471256668
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw118169.txt is:  0.8344438
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw118196.txt is:  0.10301518239539464
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw118196.txt is:  0.8571019
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw169261.txt is:  0.07626236703776136
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw169261.txt is:  0.8106589
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw169262.txt is:  0.05844485638550068
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw169262.txt is:  0.80392087
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw169264.txt is:  0.047709782670699176
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw169264.txt is:  0.69721276
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170882.txt is:  0.1157318922426976
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170882.txt is:  0.8236271
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170885.txt is:  0.11547764063584628
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170885.txt is:  0.8280502
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170908.txt is:  0.07126475308307673
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170908.txt is:  0.8230134
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170909.txt is:  0.19212266102582615
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and mlw170909.txt is:  0.85018873
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and National Environment Policy.txt is:  0.5715017306445382
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and National Environment Policy.txt is:  0.94326216
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and National forestry program.txt is:  0.678326657814355
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and National forestry program.txt is:  0.94593006
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and National Land Policy 2002.txt is:  0.25525949750187793
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and National Land Policy 2002.txt is:  0.91440105
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and ROAM for Malawi.txt is:  0.5182795977992378
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and ROAM for Malawi.txt is:  0.95384175
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and Sector Policies Response.txt is:  0.4798638150267175
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and Sector Policies Response.txt is:  0.9405683
#
# The tfidf similarity between Malawi Government National Forest Policy - June 2016.txt and Vision 2020.txt is:  0.42855644213364325
# The word2vec similarity between Malawi Government National Forest Policy - June 2016.txt and Vision 2020.txt is:  0.9485787
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw117757.txt is:  0.06946668311489544
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw117757.txt is:  0.76469994
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw118169.txt is:  0.11419292562118383
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw118169.txt is:  0.8063992
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw118196.txt is:  0.08363203485078484
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw118196.txt is:  0.8210205
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw169261.txt is:  0.10228382999308466
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw169261.txt is:  0.7670032
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw169262.txt is:  0.061261718839730396
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw169262.txt is:  0.763919
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw169264.txt is:  0.0776421351360249
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw169264.txt is:  0.66655695
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw170882.txt is:  0.15208954948436362
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw170882.txt is:  0.7872815
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw170885.txt is:  0.1442870900640606
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw170885.txt is:  0.7861357
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw170908.txt is:  0.12435863853597263
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw170908.txt is:  0.7867937
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and mlw170909.txt is:  0.2571298711022522
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and mlw170909.txt is:  0.81404734
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and National Environment Policy.txt is:  0.5621080914987691
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and National Environment Policy.txt is:  0.9317835
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and National forestry program.txt is:  0.43534346964742016
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and National forestry program.txt is:  0.9321647
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and National Land Policy 2002.txt is:  0.29867276171967533
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and National Land Policy 2002.txt is:  0.8944942
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and ROAM for Malawi.txt is:  0.4290862108150635
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and ROAM for Malawi.txt is:  0.94342
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and Sector Policies Response.txt is:  0.49256612943366707
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and Sector Policies Response.txt is:  0.92730546
#
# The tfidf similarity between Malawi Growth and Development Strategy III .txt and Vision 2020.txt is:  0.6177378204815801
# The word2vec similarity between Malawi Growth and Development Strategy III .txt and Vision 2020.txt is:  0.9515178
#
# The tfidf similarity between mlw117757.txt and mlw118169.txt is:  0.2079366269896423
# The word2vec similarity between mlw117757.txt and mlw118169.txt is:  0.91562116
#
# The tfidf similarity between mlw117757.txt and mlw118196.txt is:  0.1104569549176429
# The word2vec similarity between mlw117757.txt and mlw118196.txt is:  0.8890041
#
# The tfidf similarity between mlw117757.txt and mlw169261.txt is:  0.2465641387144814
# The word2vec similarity between mlw117757.txt and mlw169261.txt is:  0.92129844
#
# The tfidf similarity between mlw117757.txt and mlw169262.txt is:  0.2080232243258623
# The word2vec similarity between mlw117757.txt and mlw169262.txt is:  0.9251693
#
# The tfidf similarity between mlw117757.txt and mlw169264.txt is:  0.16033617944364845
# The word2vec similarity between mlw117757.txt and mlw169264.txt is:  0.7205545
#
# The tfidf similarity between mlw117757.txt and mlw170882.txt is:  0.15550955134312425
# The word2vec similarity between mlw117757.txt and mlw170882.txt is:  0.9332299
#
# The tfidf similarity between mlw117757.txt and mlw170885.txt is:  0.29291652919631395
# The word2vec similarity between mlw117757.txt and mlw170885.txt is:  0.9453989
#
# The tfidf similarity between mlw117757.txt and mlw170908.txt is:  0.21111707078161446
# The word2vec similarity between mlw117757.txt and mlw170908.txt is:  0.93054414
#
# The tfidf similarity between mlw117757.txt and mlw170909.txt is:  0.2440220829422599
# The word2vec similarity between mlw117757.txt and mlw170909.txt is:  0.9310372
#
# The tfidf similarity between mlw117757.txt and National Environment Policy.txt is:  0.09428593024558318
# The word2vec similarity between mlw117757.txt and National Environment Policy.txt is:  0.8459512
#
# The tfidf similarity between mlw117757.txt and National forestry program.txt is:  0.07706980025885533
# The word2vec similarity between mlw117757.txt and National forestry program.txt is:  0.85649884
#
# The tfidf similarity between mlw117757.txt and National Land Policy 2002.txt is:  0.08003070998637352
# The word2vec similarity between mlw117757.txt and National Land Policy 2002.txt is:  0.89320135
#
# The tfidf similarity between mlw117757.txt and ROAM for Malawi.txt is:  0.06698388156926635
# The word2vec similarity between mlw117757.txt and ROAM for Malawi.txt is:  0.8288784
#
# The tfidf similarity between mlw117757.txt and Sector Policies Response.txt is:  0.08371757476437712
# The word2vec similarity between mlw117757.txt and Sector Policies Response.txt is:  0.8477484
#
# The tfidf similarity between mlw117757.txt and Vision 2020.txt is:  0.1078838549755078
# The word2vec similarity between mlw117757.txt and Vision 2020.txt is:  0.8389125
#
# The tfidf similarity between mlw118169.txt and mlw118196.txt is:  0.1945094576596633
# The word2vec similarity between mlw118169.txt and mlw118196.txt is:  0.9003184
#
# The tfidf similarity between mlw118169.txt and mlw169261.txt is:  0.1529471549430457
# The word2vec similarity between mlw118169.txt and mlw169261.txt is:  0.9202789
#
# The tfidf similarity between mlw118169.txt and mlw169262.txt is:  0.23961711280668382
# The word2vec similarity between mlw118169.txt and mlw169262.txt is:  0.95406806
#
# The tfidf similarity between mlw118169.txt and mlw169264.txt is:  0.08184126288723931
# The word2vec similarity between mlw118169.txt and mlw169264.txt is:  0.72050583
#
# The tfidf similarity between mlw118169.txt and mlw170882.txt is:  0.27720709084601175
# The word2vec similarity between mlw118169.txt and mlw170882.txt is:  0.9580512
#
# The tfidf similarity between mlw118169.txt and mlw170885.txt is:  0.3849236646833888
# The word2vec similarity between mlw118169.txt and mlw170885.txt is:  0.95660067
#
# The tfidf similarity between mlw118169.txt and mlw170908.txt is:  0.3134516460690042
# The word2vec similarity between mlw118169.txt and mlw170908.txt is:  0.956462
#
# The tfidf similarity between mlw118169.txt and mlw170909.txt is:  0.45022088673080884
# The word2vec similarity between mlw118169.txt and mlw170909.txt is:  0.9582016
#
# The tfidf similarity between mlw118169.txt and National Environment Policy.txt is:  0.1540979508137836
# The word2vec similarity between mlw118169.txt and National Environment Policy.txt is:  0.8695438
#
# The tfidf similarity between mlw118169.txt and National forestry program.txt is:  0.11405130470596846
# The word2vec similarity between mlw118169.txt and National forestry program.txt is:  0.8814197
#
# The tfidf similarity between mlw118169.txt and National Land Policy 2002.txt is:  0.15924297335820947
# The word2vec similarity between mlw118169.txt and National Land Policy 2002.txt is:  0.91400546
#
# The tfidf similarity between mlw118169.txt and ROAM for Malawi.txt is:  0.11109324997587952
# The word2vec similarity between mlw118169.txt and ROAM for Malawi.txt is:  0.8502388
#
# The tfidf similarity between mlw118169.txt and Sector Policies Response.txt is:  0.08487184208625037
# The word2vec similarity between mlw118169.txt and Sector Policies Response.txt is:  0.8575411
#
# The tfidf similarity between mlw118169.txt and Vision 2020.txt is:  0.12574078537664488
# The word2vec similarity between mlw118169.txt and Vision 2020.txt is:  0.8686435
#
# The tfidf similarity between mlw118196.txt and mlw169261.txt is:  0.12188803045685644
# The word2vec similarity between mlw118196.txt and mlw169261.txt is:  0.9004879
#
# The tfidf similarity between mlw118196.txt and mlw169262.txt is:  0.10787197719565005
# The word2vec similarity between mlw118196.txt and mlw169262.txt is:  0.89944726
#
# The tfidf similarity between mlw118196.txt and mlw169264.txt is:  0.10869354496798499
# The word2vec similarity between mlw118196.txt and mlw169264.txt is:  0.7448349
#
# The tfidf similarity between mlw118196.txt and mlw170882.txt is:  0.1447643146965255
# The word2vec similarity between mlw118196.txt and mlw170882.txt is:  0.91518426
#
# The tfidf similarity between mlw118196.txt and mlw170885.txt is:  0.15289103818874808
# The word2vec similarity between mlw118196.txt and mlw170885.txt is:  0.92405677
#
# The tfidf similarity between mlw118196.txt and mlw170908.txt is:  0.18244824079852345
# The word2vec similarity between mlw118196.txt and mlw170908.txt is:  0.91224986
#
# The tfidf similarity between mlw118196.txt and mlw170909.txt is:  0.1802820779142184
# The word2vec similarity between mlw118196.txt and mlw170909.txt is:  0.92453957
#
# The tfidf similarity between mlw118196.txt and National Environment Policy.txt is:  0.10715209902126127
# The word2vec similarity between mlw118196.txt and National Environment Policy.txt is:  0.8854922
#
# The tfidf similarity between mlw118196.txt and National forestry program.txt is:  0.119741818781229
# The word2vec similarity between mlw118196.txt and National forestry program.txt is:  0.8869396
#
# The tfidf similarity between mlw118196.txt and National Land Policy 2002.txt is:  0.11725454666175603
# The word2vec similarity between mlw118196.txt and National Land Policy 2002.txt is:  0.9144964
#
# The tfidf similarity between mlw118196.txt and ROAM for Malawi.txt is:  0.15749824914848096
# The word2vec similarity between mlw118196.txt and ROAM for Malawi.txt is:  0.886149
#
# The tfidf similarity between mlw118196.txt and Sector Policies Response.txt is:  0.10123469054831792
# The word2vec similarity between mlw118196.txt and Sector Policies Response.txt is:  0.895607
#
# The tfidf similarity between mlw118196.txt and Vision 2020.txt is:  0.10320246790533355
# The word2vec similarity between mlw118196.txt and Vision 2020.txt is:  0.87303936
#
# The tfidf similarity between mlw169261.txt and mlw169262.txt is:  0.7221585209120661
# The word2vec similarity between mlw169261.txt and mlw169262.txt is:  0.95636356
#
# The tfidf similarity between mlw169261.txt and mlw169264.txt is:  0.2209368709870276
# The word2vec similarity between mlw169261.txt and mlw169264.txt is:  0.7126925
#
# The tfidf similarity between mlw169261.txt and mlw170882.txt is:  0.5239876628641348
# The word2vec similarity between mlw169261.txt and mlw170882.txt is:  0.9406494
#
# The tfidf similarity between mlw169261.txt and mlw170885.txt is:  0.6003902359718931
# The word2vec similarity between mlw169261.txt and mlw170885.txt is:  0.9515534
#
# The tfidf similarity between mlw169261.txt and mlw170908.txt is:  0.37288809664146927
# The word2vec similarity between mlw169261.txt and mlw170908.txt is:  0.93559873
#
# The tfidf similarity between mlw169261.txt and mlw170909.txt is:  0.3791017327468709
# The word2vec similarity between mlw169261.txt and mlw170909.txt is:  0.9386157
#
# The tfidf similarity between mlw169261.txt and National Environment Policy.txt is:  0.1357599183667111
# The word2vec similarity between mlw169261.txt and National Environment Policy.txt is:  0.82644016
#
# The tfidf similarity between mlw169261.txt and National forestry program.txt is:  0.14740962376527575
# The word2vec similarity between mlw169261.txt and National forestry program.txt is:  0.8517121
#
# The tfidf similarity between mlw169261.txt and National Land Policy 2002.txt is:  0.4940123779922592
# The word2vec similarity between mlw169261.txt and National Land Policy 2002.txt is:  0.88821846
#
# The tfidf similarity between mlw169261.txt and ROAM for Malawi.txt is:  0.15819865148699888
# The word2vec similarity between mlw169261.txt and ROAM for Malawi.txt is:  0.8283942
#
# The tfidf similarity between mlw169261.txt and Sector Policies Response.txt is:  0.10687407074798169
# The word2vec similarity between mlw169261.txt and Sector Policies Response.txt is:  0.8372272
#
# The tfidf similarity between mlw169261.txt and Vision 2020.txt is:  0.13525816820041411
# The word2vec similarity between mlw169261.txt and Vision 2020.txt is:  0.82428575
#
# The tfidf similarity between mlw169262.txt and mlw169264.txt is:  0.19820351083312765
# The word2vec similarity between mlw169262.txt and mlw169264.txt is:  0.71640295
#
# The tfidf similarity between mlw169262.txt and mlw170882.txt is:  0.28990851401663287
# The word2vec similarity between mlw169262.txt and mlw170882.txt is:  0.9641582
#
# The tfidf similarity between mlw169262.txt and mlw170885.txt is:  0.3893556558239462
# The word2vec similarity between mlw169262.txt and mlw170885.txt is:  0.9594234
#
# The tfidf similarity between mlw169262.txt and mlw170908.txt is:  0.32809212609748256
# The word2vec similarity between mlw169262.txt and mlw170908.txt is:  0.9576484
#
# The tfidf similarity between mlw169262.txt and mlw170909.txt is:  0.3205731962997239
# The word2vec similarity between mlw169262.txt and mlw170909.txt is:  0.9596071
#
# The tfidf similarity between mlw169262.txt and National Environment Policy.txt is:  0.10724872522228775
# The word2vec similarity between mlw169262.txt and National Environment Policy.txt is:  0.8351469
#
# The tfidf similarity between mlw169262.txt and National forestry program.txt is:  0.0936150852682953
# The word2vec similarity between mlw169262.txt and National forestry program.txt is:  0.8519492
#
# The tfidf similarity between mlw169262.txt and National Land Policy 2002.txt is:  0.18641562453255442
# The word2vec similarity between mlw169262.txt and National Land Policy 2002.txt is:  0.8966457
#
# The tfidf similarity between mlw169262.txt and ROAM for Malawi.txt is:  0.0822029300051633
# The word2vec similarity between mlw169262.txt and ROAM for Malawi.txt is:  0.8281661
#
# The tfidf similarity between mlw169262.txt and Sector Policies Response.txt is:  0.06878339020227046
# The word2vec similarity between mlw169262.txt and Sector Policies Response.txt is:  0.83279496
#
# The tfidf similarity between mlw169262.txt and Vision 2020.txt is:  0.07426999540946229
# The word2vec similarity between mlw169262.txt and Vision 2020.txt is:  0.8277056
#
# The tfidf similarity between mlw169264.txt and mlw170882.txt is:  0.04041324977726036
# The word2vec similarity between mlw169264.txt and mlw170882.txt is:  0.7
#
# The tfidf similarity between mlw169264.txt and mlw170885.txt is:  0.126937503587111
# The word2vec similarity between mlw169264.txt and mlw170885.txt is:  0.69398093
#
# The tfidf similarity between mlw169264.txt and mlw170908.txt is:  0.07823334803102883
# The word2vec similarity between mlw169264.txt and mlw170908.txt is:  0.6962472
#
# The tfidf similarity between mlw169264.txt and mlw170909.txt is:  0.1557322735710966
# The word2vec similarity between mlw169264.txt and mlw170909.txt is:  0.70339215
#
# The tfidf similarity between mlw169264.txt and National Environment Policy.txt is:  0.05904836946639931
# The word2vec similarity between mlw169264.txt and National Environment Policy.txt is:  0.65957385
#
# The tfidf similarity between mlw169264.txt and National forestry program.txt is:  0.04757367799979069
# The word2vec similarity between mlw169264.txt and National forestry program.txt is:  0.6573923
#
# The tfidf similarity between mlw169264.txt and National Land Policy 2002.txt is:  0.04770975315951585
# The word2vec similarity between mlw169264.txt and National Land Policy 2002.txt is:  0.67247295
#
# The tfidf similarity between mlw169264.txt and ROAM for Malawi.txt is:  0.05830168323147076
# The word2vec similarity between mlw169264.txt and ROAM for Malawi.txt is:  0.67944527
#
# The tfidf similarity between mlw169264.txt and Sector Policies Response.txt is:  0.08483902079804286
# The word2vec similarity between mlw169264.txt and Sector Policies Response.txt is:  0.65420043
#
# The tfidf similarity between mlw169264.txt and Vision 2020.txt is:  0.07966510223661116
# The word2vec similarity between mlw169264.txt and Vision 2020.txt is:  0.66728795
#
# The tfidf similarity between mlw170882.txt and mlw170885.txt is:  0.7586092891666851
# The word2vec similarity between mlw170882.txt and mlw170885.txt is:  0.97888577
#
# The tfidf similarity between mlw170882.txt and mlw170908.txt is:  0.4231593077035733
# The word2vec similarity between mlw170882.txt and mlw170908.txt is:  0.9829482
#
# The tfidf similarity between mlw170882.txt and mlw170909.txt is:  0.5056131737447975
# The word2vec similarity between mlw170882.txt and mlw170909.txt is:  0.98623294
#
# The tfidf similarity between mlw170882.txt and National Environment Policy.txt is:  0.21983349523275827
# The word2vec similarity between mlw170882.txt and National Environment Policy.txt is:  0.87606704
#
# The tfidf similarity between mlw170882.txt and National forestry program.txt is:  0.20984454294958182
# The word2vec similarity between mlw170882.txt and National forestry program.txt is:  0.8842699
#
# The tfidf similarity between mlw170882.txt and National Land Policy 2002.txt is:  0.8140495714730366
# The word2vec similarity between mlw170882.txt and National Land Policy 2002.txt is:  0.9369403
#
# The tfidf similarity between mlw170882.txt and ROAM for Malawi.txt is:  0.23069070033098846
# The word2vec similarity between mlw170882.txt and ROAM for Malawi.txt is:  0.8549379
#
# The tfidf similarity between mlw170882.txt and Sector Policies Response.txt is:  0.10912321090662674
# The word2vec similarity between mlw170882.txt and Sector Policies Response.txt is:  0.87000805
#
# The tfidf similarity between mlw170882.txt and Vision 2020.txt is:  0.16000654711179504
# The word2vec similarity between mlw170882.txt and Vision 2020.txt is:  0.86914027
#
# The tfidf similarity between mlw170885.txt and mlw170908.txt is:  0.4509315685891888
# The word2vec similarity between mlw170885.txt and mlw170908.txt is:  0.9724052
#
# The tfidf similarity between mlw170885.txt and mlw170909.txt is:  0.5569575933036833
# The word2vec similarity between mlw170885.txt and mlw170909.txt is:  0.9786779
#
# The tfidf similarity between mlw170885.txt and National Environment Policy.txt is:  0.23334193150497481
# The word2vec similarity between mlw170885.txt and National Environment Policy.txt is:  0.8785192
#
# The tfidf similarity between mlw170885.txt and National forestry program.txt is:  0.21925135857567196
# The word2vec similarity between mlw170885.txt and National forestry program.txt is:  0.88321024
#
# The tfidf similarity between mlw170885.txt and National Land Policy 2002.txt is:  0.7046306635451861
# The word2vec similarity between mlw170885.txt and National Land Policy 2002.txt is:  0.93764526
#
# The tfidf similarity between mlw170885.txt and ROAM for Malawi.txt is:  0.23274564601598613
# The word2vec similarity between mlw170885.txt and ROAM for Malawi.txt is:  0.85799813
#
# The tfidf similarity between mlw170885.txt and Sector Policies Response.txt is:  0.13638576552023846
# The word2vec similarity between mlw170885.txt and Sector Policies Response.txt is:  0.872265
#
# The tfidf similarity between mlw170885.txt and Vision 2020.txt is:  0.1779341842390441
# The word2vec similarity between mlw170885.txt and Vision 2020.txt is:  0.862614
#
# The tfidf similarity between mlw170908.txt and mlw170909.txt is:  0.4752853888418053
# The word2vec similarity between mlw170908.txt and mlw170909.txt is:  0.9858586
#
# The tfidf similarity between mlw170908.txt and National Environment Policy.txt is:  0.14332381741825356
# The word2vec similarity between mlw170908.txt and National Environment Policy.txt is:  0.87239885
#
# The tfidf similarity between mlw170908.txt and National forestry program.txt is:  0.1184999035638736
# The word2vec similarity between mlw170908.txt and National forestry program.txt is:  0.88166267
#
# The tfidf similarity between mlw170908.txt and National Land Policy 2002.txt is:  0.33368340900647864
# The word2vec similarity between mlw170908.txt and National Land Policy 2002.txt is:  0.9324714
#
# The tfidf similarity between mlw170908.txt and ROAM for Malawi.txt is:  0.13793656684256475
# The word2vec similarity between mlw170908.txt and ROAM for Malawi.txt is:  0.8565185
#
# The tfidf similarity between mlw170908.txt and Sector Policies Response.txt is:  0.09195596095666536
# The word2vec similarity between mlw170908.txt and Sector Policies Response.txt is:  0.8670782
#
# The tfidf similarity between mlw170908.txt and Vision 2020.txt is:  0.11467962943424019
# The word2vec similarity between mlw170908.txt and Vision 2020.txt is:  0.86741424
#
# The tfidf similarity between mlw170909.txt and National Environment Policy.txt is:  0.2728780129341231
# The word2vec similarity between mlw170909.txt and National Environment Policy.txt is:  0.9001641
#
# The tfidf similarity between mlw170909.txt and National forestry program.txt is:  0.20658267429347432
# The word2vec similarity between mlw170909.txt and National forestry program.txt is:  0.90523016
#
# The tfidf similarity between mlw170909.txt and National Land Policy 2002.txt is:  0.45910961203098083
# The word2vec similarity between mlw170909.txt and National Land Policy 2002.txt is:  0.95095056
#
# The tfidf similarity between mlw170909.txt and ROAM for Malawi.txt is:  0.21633335071938375
# The word2vec similarity between mlw170909.txt and ROAM for Malawi.txt is:  0.8771019
#
# The tfidf similarity between mlw170909.txt and Sector Policies Response.txt is:  0.21675359594566596
# The word2vec similarity between mlw170909.txt and Sector Policies Response.txt is:  0.8912145
#
# The tfidf similarity between mlw170909.txt and Vision 2020.txt is:  0.2713710483134594
# The word2vec similarity between mlw170909.txt and Vision 2020.txt is:  0.89281833
#
# The tfidf similarity between National Environment Policy.txt and National forestry program.txt is:  0.5043932466888011
# The word2vec similarity between National Environment Policy.txt and National forestry program.txt is:  0.9776805
#
# The tfidf similarity between National Environment Policy.txt and National Land Policy 2002.txt is:  0.3826555180000822
# The word2vec similarity between National Environment Policy.txt and National Land Policy 2002.txt is:  0.9705282
#
# The tfidf similarity between National Environment Policy.txt and ROAM for Malawi.txt is:  0.46124417787238936
# The word2vec similarity between National Environment Policy.txt and ROAM for Malawi.txt is:  0.9631103
#
# The tfidf similarity between National Environment Policy.txt and Sector Policies Response.txt is:  0.582232721459315
# The word2vec similarity between National Environment Policy.txt and Sector Policies Response.txt is:  0.9774544
#
# The tfidf similarity between National Environment Policy.txt and Vision 2020.txt is:  0.564787730132371
# The word2vec similarity between National Environment Policy.txt and Vision 2020.txt is:  0.97120655
#
# The tfidf similarity between National forestry program.txt and National Land Policy 2002.txt is:  0.3663234239942569
# The word2vec similarity between National forestry program.txt and National Land Policy 2002.txt is:  0.97622913
#
# The tfidf similarity between National forestry program.txt and ROAM for Malawi.txt is:  0.5873523816567229
# The word2vec similarity between National forestry program.txt and ROAM for Malawi.txt is:  0.9792579
#
# The tfidf similarity between National forestry program.txt and Sector Policies Response.txt is:  0.4808913611578325
# The word2vec similarity between National forestry program.txt and Sector Policies Response.txt is:  0.9848429
#
# The tfidf similarity between National forestry program.txt and Vision 2020.txt is:  0.49747266980774163
# The word2vec similarity between National forestry program.txt and Vision 2020.txt is:  0.9795877
#
# The tfidf similarity between National Land Policy 2002.txt and ROAM for Malawi.txt is:  0.39169391268366993
# The word2vec similarity between National Land Policy 2002.txt and ROAM for Malawi.txt is:  0.9570895
#
# The tfidf similarity between National Land Policy 2002.txt and Sector Policies Response.txt is:  0.32116611409492174
# The word2vec similarity between National Land Policy 2002.txt and Sector Policies Response.txt is:  0.97083557
#
# The tfidf similarity between National Land Policy 2002.txt and Vision 2020.txt is:  0.33866222104654814
# The word2vec similarity between National Land Policy 2002.txt and Vision 2020.txt is:  0.96510255
#
# The tfidf similarity between ROAM for Malawi.txt and Sector Policies Response.txt is:  0.5020001550259765
# The word2vec similarity between ROAM for Malawi.txt and Sector Policies Response.txt is:  0.9792276
#
# The tfidf similarity between ROAM for Malawi.txt and Vision 2020.txt is:  0.44231660990658306
# The word2vec similarity between ROAM for Malawi.txt and Vision 2020.txt is:  0.96203095
#
# The tfidf similarity between Sector Policies Response.txt and Vision 2020.txt is:  0.5118163865662081
# The word2vec similarity between Sector Policies Response.txt and Vision 2020.txt is:  0.9750327

# %%
np.savetxt(filepath_exported+"tfidf_matrix.csv", matrix_tfidf, delimiter=",")

# %%
np.savetxt(filepath_exported+"word2vec_matrix.csv", matrix_word2vec, delimiter=",")
